# %% [markdown]
# ## Arboles de decisión

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("C:/Users/zul_l/Downloads/wine.data")
data.head()
# Out:
#    Clase  Alcohol  AcidoMalico  Ceniza  AlcalinidadDeLACeniza  Magnesio  \
# 0      1    14.23         1.71    2.43                   15.6       127
# 1      1    13.20         1.78    2.14                   11.2       100
# 2      1    13.16         2.36    2.67                   18.6       101
# 3      1    14.37         1.95    2.50                   16.8       113
# 4      1    13.24         2.59    2.87                   21.0       118
#
#    FenolesTotales  Flavonoides  FenolesnoFlavonoides  Proantocianinas  \
# 0            2.80         3.06                  0.28             2.29
# 1            2.65         2.76                  0.26             1.28
# 2            2.80         3.24                  0.30             2.81
# 3            3.85         3.49                  0.24             2.18
# 4            2.80         2.69                  0.39             1.82
#
#    IntensidadDelColor  Tono  OD280  Prolina
# 0                5.64  1.04   3.92     1065
# ...

# %%
data.shape
# Out:
# (178, 14)

# %%
data.describe()
# Out:
#             Clase     Alcohol  AcidoMalico      Ceniza  AlcalinidadDeLACeniza  \
# count  178.000000  178.000000   178.000000  178.000000             178.000000
# mean     1.938202   13.000618     2.336348    2.366517              19.494944
# std      0.775035    0.811827     1.117146    0.274344               3.339564
# min      1.000000   11.030000     0.740000    1.360000              10.600000
# 25%      1.000000   12.362500     1.602500    2.210000              17.200000
# 50%      2.000000   13.050000     1.865000    2.360000              19.500000
# 75%      3.000000   13.677500     3.082500    2.557500              21.500000
# max      3.000000   14.830000     5.800000    3.230000              30.000000
#
#          Magnesio  FenolesTotales  Flavonoides  FenolesnoFlavonoides  \
# count  178.000000      178.000000   178.000000            178.000000
# mean    99.741573        2.295112     2.029270              0.361854
# ...

# %%
predictors_col = ["Alcohol","AcidoMalico","Ceniza","AlcalinidadDeLACeniza","Magnesio","FenolesTotales","Flavonoides","FenolesnoFlavonoides","Proantocianinas","IntensidadDelColor","Tono","OD280","Prolina"]
target_col = ['Clase']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.2,random_state=42)

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.5, 0.9, 'x[9] <= 3.82\ngini = 0.659\nsamples = 142\nvalue = [45, 57, 40]'),
#  Text(0.3, 0.7, 'x[12] <= 1002.5\ngini = 0.109\nsamples = 52\nvalue = [3, 49, 0]'),
#  Text(0.2, 0.5, 'x[2] <= 3.07\ngini = 0.039\nsamples = 50\nvalue = [1, 49, 0]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 49\nvalue = [0, 49, 0]'),
#  Text(0.3, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.7, 0.7, 'x[6] <= 1.4\ngini = 0.577\nsamples = 90\nvalue = [42, 8, 40]'),
#  Text(0.6, 0.5, 'gini = 0.0\nsamples = 40\nvalue = [0, 0, 40]'),
#  Text(0.8, 0.5, 'x[12] <= 724.5\ngini = 0.269\nsamples = 50\nvalue = [42, 8, 0]'),
#  Text(0.7, 0.3, 'x[0] <= 13.145\ngini = 0.198\nsamples = 9\nvalue = [1, 8, 0]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]')]

# %%
predicciones = arbol.predict(X_test)

# %%
pd.crosstab(np.array([y[0]for y in y_test.values.tolist()]),predicciones,rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones   1   2  3
# Actual
# 1             13   1  0
# 2              0  14  0
# 3              1   0  7

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.9444444444444444
